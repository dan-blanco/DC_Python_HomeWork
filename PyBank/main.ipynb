# %%
"""
Davit Cuedari 
Rutgers ~ FinTech BootCamp --- Python HomeWork --- due Saturday, March 26, 2021

The task is to create a Python script that analyzes the records to calculate each of the following:

        1- The total number of months included in the dataset.

        2- The net total amount of Profit/Losses over the entire period.

        3- The average of the changes in Profit/Losses over the entire period.

        4- The greatest increase in profits (date and amount) over the entire period.

        5- The greatest decrease in losses (date and amount) over the entire period.
"""
# To start, first it is necessary to import a few modules:

import os
import csv
from numpy import average

# After importing the module we have to open the file with csv function 
csvpath = os.path.join("/Users/ddevii/Rutgers/DC_Python_HomeWork/PyBank/Resources/budget_data.csv")

# I have to set an output file where I want the results of the exercise to be written:
output_document_path = "/Users/ddevii/Rutgers/DC_Python_HomeWork/PyBank/Resources/output_document.txt"

# I need to create a few variables that I am going to transfer and fill with data later on the exercise:
tot_number_of_months = []
tot_revenue = []
changes_in_revenue = 0
changes_in_months = []
values_before_change = 0

# From the csv file extracting the date to find the total number of months included in the dataset:
with open(csvpath) as csvfile:                          #first we open the csv file format of dataset
    csvreader = csv.reader(csvfile, delimiter=",")      #then we use the csv function to read and separate with a comma
    cvsheader = next(csvreader)                         #we do this to avoid counting the header ("Date") in the total number of months

    for row in csvreader:
        tot_number_of_months.append(row[0])
        tot_revenue.append(row[1])
        print(tot_revenue)
# Out:
# ['867884']
# ['867884', '984655']
# ['867884', '984655', '322013']
# ['867884', '984655', '322013', '-69417']
# ['867884', '984655', '322013', '-69417', '310503']
# ['867884', '984655', '322013', '-69417', '310503', '522857']
# ['867884', '984655', '322013', '-69417', '310503', '522857', '1033096']
# ['867884', '984655', '322013', '-69417', '310503', '522857', '1033096', '604885']
# ['867884', '984655', '322013', '-69417', '310503', '522857', '1033096', '604885', '-216386']
# ['867884', '984655', '322013', '-69417', '310503', '522857', '1033096', '604885', '-216386', '477532']
# ['867884', '984655', '322013', '-69417', '310503', '522857', '1033096', '604885', '-216386', '477532', '893810']
# ['867884', '984655', '322013', '-69417', '310503', '522857', '1033096', '604885', '-216386', '477532', '893810', '-80353']
# ['867884', '984655', '322013', '-69417', '310503', '522857', '1033096', '604885', '-216386', '477532', '893810', '-80353', '779806']
# ...
